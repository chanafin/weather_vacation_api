# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# !pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in c:\users\chris\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\chris\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for i in lat_lngs:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities

df = pd.DataFrame(cities)
df['Country'] = ''
df['Date'] = ''
df['Lat'] = ''
df['Lng'] = ''
df['Max Temp'] = ''
df['Humidity'] = ''
df['Cloudiness'] = ''
df['Wind Speed'] = ''
df.rename(columns = {0 : 'City'}, inplace = True)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
for index, row in df.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    city = row['City']
    response = requests.get(url + 'appid=' + weather_api_key + '&q=' + city + "&units=Imperial")
    response = response.json()
    try:
        print(f'{city} has been added to the DataFrame.')
        df.loc[index, 'Lat'] = response['coord']['lat']
        df.loc[index, 'Lng'] = response['coord']['lon']
        df.loc[index, 'Max Temp'] = response['main']['temp_max']
        df.loc[index, 'Humidity'] = response['main']['humidity']
        df.loc[index, 'Cloudiness'] = response['clouds']['all']
        df.loc[index, 'Wind Speed'] = response['wind']['speed']
        df.loc[index, 'Country'] = response['sys']['country']
        df.loc[index, 'Date'] = response['dt']
    except(KeyError, IndexError):
        print('Missing City ... Skipping')
# Out:
# west wendover has been added to the DataFrame.
# qaanaaq has been added to the DataFrame.
# tire has been added to the DataFrame.
# oussouye has been added to the DataFrame.
# mataura has been added to the DataFrame.
# cabo san lucas has been added to the DataFrame.
# haines junction has been added to the DataFrame.
# haapiti has been added to the DataFrame.
# vale has been added to the DataFrame.
# rikitea has been added to the DataFrame.
# okhotsk has been added to the DataFrame.
# illoqqortoormiut has been added to the DataFrame.
# Missing City ... Skipping
# amderma has been added to the DataFrame.
# Missing City ... Skipping
# saskylakh has been added to the DataFrame.
# mahebourg has been added to the DataFrame.
# khatanga has been added to the DataFrame.
# castro has been added to the DataFrame.
# tasiilaq has been added to the DataFrame.
# kapaa has been added to the DataFrame.
# cabra has been added to the DataFrame.
# baruun-urt has been added to the DataFrame.
# port augusta has been added to the DataFrame.
# tuktoyaktuk has been added to the DataFrame.
# miranda has been added to the DataFrame.
# hilo has been added to the DataFrame.
# attawapiskat has been added to the DataFrame.
# Missing City ... Skipping
# georgetown has been added to the DataFrame.
# kampot has been added to the DataFrame.
# lashio has been added to the DataFrame.
# atuona has been added to the DataFrame.
# albany has been added to the DataFrame.
# boyuibe has been added to the DataFrame.
# killam has been added to the DataFrame.
# adrar has been added to the DataFrame.
# the valley has been added to the DataFrame.
# ushuaia has been added to the DataFrame.
# launceston has been added to the DataFrame.
# ponta do sol has been added to the DataFrame.
# kamaishi has been added to the DataFrame.
# knysna has been added to the DataFrame.
# bengkulu has been added to the DataFrame.
# bambanglipuro has been added to the DataFrame.
# hermanus has been added to the DataFrame.
# gat has been added to the DataFrame.
# taoudenni has been added to the DataFrame.
# bethel has been added to the DataFrame.
# agadir has been added to the DataFrame.
# kargasok has been added to the DataFrame.
# kavieng has been added to the DataFrame.
# vaini has been added to the DataFrame.
# north bend has been added to the DataFrame.
# sao filipe has been added to the DataFrame.
# shellbrook has been added to the DataFrame.
# milingimbi has been added to the DataFrame.
# Missing City ... Skipping
# jining has been added to the DataFrame.
# new norfolk has been added to the DataFrame.
# herat has been added to the DataFrame.
# avarua has been added to the DataFrame.
# punta arenas has been added to the DataFrame.
# kavaratti has been added to the DataFrame.
# hithadhoo has been added to the DataFrame.
# arraial do cabo has been added to the DataFrame.
# salalah has been added to the DataFrame.
# lenger has been added to the DataFrame.
# dwarka has been added to the DataFrame.
# provideniya has been added to the DataFrame.
# hurghada has been added to the DataFrame.
# lolua has been added to the DataFrame.
# Missing City ... Skipping
# lavrentiya has been added to the DataFrame.
# yumen has been added to the DataFrame.
# eldoret has been added to the DataFrame.
# basoko has been added to the DataFrame.
# malamig has been added to the DataFrame.
# cape town has been added to the DataFrame.
# namibe has been added to the DataFrame.
# butaritari has been added to the DataFrame.
# bredasdorp has been added to the DataFrame.
# zarubino has been added to the DataFrame.
# kattivakkam has been added to the DataFrame.
# bluff has been added to the DataFrame.
# meulaboh has been added to the DataFrame.
# te anau has been added to the DataFrame.
# upernavik has been added to the DataFrame.
# qabaqcol has been added to the DataFrame.
# yellowknife has been added to the DataFrame.
# barrow has been added to the DataFrame.
# pevek has been added to the DataFrame.
# halalo has been added to the DataFrame.
# Missing City ... Skipping
# vila do maio has been added to the DataFrame.
# hobart has been added to the DataFrame.
# port alfred has been added to the DataFrame.
# kinna has been added to the DataFrame.
# fortuna foothills has been added to the DataFrame.
# belushya guba has been added to the DataFrame.
# Missing City ... Skipping
# saint-philippe has been added to the DataFrame.
# taolanaro has been added to the DataFrame.
# Missing City ... Skipping
# ndele has been added to the DataFrame.
# busselton has been added to the DataFrame.
# tubruq has been added to the DataFrame.
# Missing City ... Skipping
# labuhan has been added to the DataFrame.
# simao has been added to the DataFrame.
# skibbereen has been added to the DataFrame.
# hibbing has been added to the DataFrame.
# dingle has been added to the DataFrame.
# husi has been added to the DataFrame.
# saldanha has been added to the DataFrame.
# hambantota has been added to the DataFrame.
# cabo rojo has been added to the DataFrame.
# abu jubayhah has been added to the DataFrame.
# Missing City ... Skipping
# torbay has been added to the DataFrame.
# chokurdakh has been added to the DataFrame.
# guerrero negro has been added to the DataFrame.
# aras has been added to the DataFrame.
# bambous virieux has been added to the DataFrame.
# izberbash has been added to the DataFrame.
# souillac has been added to the DataFrame.
# coihaique has been added to the DataFrame.
# muros has been added to the DataFrame.
# esperance has been added to the DataFrame.
# chimbarongo has been added to the DataFrame.
# abalak has been added to the DataFrame.
# cidreira has been added to the DataFrame.
# carnarvon has been added to the DataFrame.
# umm kaddadah has been added to the DataFrame.
# vetapalem has been added to the DataFrame.
# tilichiki has been added to the DataFrame.
# pilot butte has been added to the DataFrame.
# norman wells has been added to the DataFrame.
# jumla has been added to the DataFrame.
# boden has been added to the DataFrame.
# vaitupu has been added to the DataFrame.
# Missing City ... Skipping
# villazon has been added to the DataFrame.
# sochi has been added to the DataFrame.
# kwinana has been added to the DataFrame.
# piacabucu has been added to the DataFrame.
# lasa has been added to the DataFrame.
# port lincoln has been added to the DataFrame.
# lichuan has been added to the DataFrame.
# east london has been added to the DataFrame.
# verkhniy mamon has been added to the DataFrame.
# airai has been added to the DataFrame.
# shubarkuduk has been added to the DataFrame.
# naze has been added to the DataFrame.
# todos santos has been added to the DataFrame.
# karavayevo has been added to the DataFrame.
# noumea has been added to the DataFrame.
# bengkalis has been added to the DataFrame.
# Missing City ... Skipping
# dien bien has been added to the DataFrame.
# Missing City ... Skipping
# mwinilunga has been added to the DataFrame.
# arman has been added to the DataFrame.
# puerto ayora has been added to the DataFrame.
# sakakah has been added to the DataFrame.
# bathsheba has been added to the DataFrame.
# talas has been added to the DataFrame.
# itarema has been added to the DataFrame.
# barentsburg has been added to the DataFrame.
# Missing City ... Skipping
# lompoc has been added to the DataFrame.
# kruisfontein has been added to the DataFrame.
# vanavara has been added to the DataFrame.
# villarrica has been added to the DataFrame.
# curuguaty has been added to the DataFrame.
# caxito has been added to the DataFrame.
# mar del plata has been added to the DataFrame.
# waipawa has been added to the DataFrame.
# rungata has been added to the DataFrame.
# Missing City ... Skipping
# victoria has been added to the DataFrame.
# chokwe has been added to the DataFrame.
# jamestown has been added to the DataFrame.
# isangel has been added to the DataFrame.
# rawson has been added to the DataFrame.
# port macquarie has been added to the DataFrame.
# keti bandar has been added to the DataFrame.
# satitoa has been added to the DataFrame.
# Missing City ... Skipping
# nizhneyansk has been added to the DataFrame.
# Missing City ... Skipping
# makakilo city has been added to the DataFrame.
# mirandopolis has been added to the DataFrame.
# hofn has been added to the DataFrame.
# katsuura has been added to the DataFrame.
# keflavik has been added to the DataFrame.
# palabuhanratu has been added to the DataFrame.
# Missing City ... Skipping
# port moresby has been added to the DataFrame.
# kaitangata has been added to the DataFrame.
# nome has been added to the DataFrame.
# formoso do araguaia has been added to the DataFrame.
# Missing City ... Skipping
# bada has been added to the DataFrame.
# sinnamary has been added to the DataFrame.
# sioux lookout has been added to the DataFrame.
# udachnyy has been added to the DataFrame.
# yovon has been added to the DataFrame.
# eureka has been added to the DataFrame.
# umzimvubu has been added to the DataFrame.
# Missing City ... Skipping
# lucapa has been added to the DataFrame.
# severo-kurilsk has been added to the DataFrame.
# ngama has been added to the DataFrame.
# deputatskiy has been added to the DataFrame.
# saint-joseph has been added to the DataFrame.
# loukhi has been added to the DataFrame.
# nemuro has been added to the DataFrame.
# menongue has been added to the DataFrame.
# canon city has been added to the DataFrame.
# kahului has been added to the DataFrame.
# whitehorse has been added to the DataFrame.
# sabla has been added to the DataFrame.
# aksehir has been added to the DataFrame.
# luanda has been added to the DataFrame.
# camacupa has been added to the DataFrame.
# vila velha has been added to the DataFrame.
# marzuq has been added to the DataFrame.
# rach gia has been added to the DataFrame.
# maniitsoq has been added to the DataFrame.
# polyarnyy has been added to the DataFrame.
# eenhana has been added to the DataFrame.
# yenagoa has been added to the DataFrame.
# manado has been added to the DataFrame.
# port-gentil has been added to the DataFrame.
# aykhal has been added to the DataFrame.
# tautira has been added to the DataFrame.
# shelton has been added to the DataFrame.
# huancabamba has been added to the DataFrame.
# kirakira has been added to the DataFrame.
# ballater has been added to the DataFrame.
# dikson has been added to the DataFrame.
# lerwick has been added to the DataFrame.
# hun has been added to the DataFrame.
# mys shmidta has been added to the DataFrame.
# Missing City ... Skipping
# ahumada has been added to the DataFrame.
# Missing City ... Skipping
# mangan has been added to the DataFrame.
# la ronge has been added to the DataFrame.
# roma has been added to the DataFrame.
# abnub has been added to the DataFrame.
# petropavlovsk-kamchatskiy has been added to the DataFrame.
# yulara has been added to the DataFrame.
# iqaluit has been added to the DataFrame.
# ondangwa has been added to the DataFrame.
# bay saint louis has been added to the DataFrame.
# ngunguru has been added to the DataFrame.
# fushan has been added to the DataFrame.
# lebu has been added to the DataFrame.
# ostrovnoy has been added to the DataFrame.
# puerto colombia has been added to the DataFrame.
# palana has been added to the DataFrame.
# constitucion has been added to the DataFrame.
# berezanskaya has been added to the DataFrame.
# yangambi has been added to the DataFrame.
# smolenka has been added to the DataFrame.
# andenes has been added to the DataFrame.
# talara has been added to the DataFrame.
# siocon has been added to the DataFrame.
# lahad datu has been added to the DataFrame.
# goderich has been added to the DataFrame.
# alice springs has been added to the DataFrame.
# bosaso has been added to the DataFrame.
# viransehir has been added to the DataFrame.
# sambava has been added to the DataFrame.
# cherskiy has been added to the DataFrame.
# san quintin has been added to the DataFrame.
# zima has been added to the DataFrame.
# ambilobe has been added to the DataFrame.
# zacualpan has been added to the DataFrame.
# ilulissat has been added to the DataFrame.
# san patricio has been added to the DataFrame.
# porto santo has been added to the DataFrame.
# buala has been added to the DataFrame.
# warangal has been added to the DataFrame.
# saint george has been added to the DataFrame.
# avera has been added to the DataFrame.
# porto novo has been added to the DataFrame.
# orocue has been added to the DataFrame.
# nioro has been added to the DataFrame.
# leshukonskoye has been added to the DataFrame.
# port blair has been added to the DataFrame.
# port elizabeth has been added to the DataFrame.
# oranjemund has been added to the DataFrame.
# ornskoldsvik has been added to the DataFrame.
# saint-pierre has been added to the DataFrame.
# parana has been added to the DataFrame.
# kefalos has been added to the DataFrame.
# koungou has been added to the DataFrame.
# troitsko-pechorsk has been added to the DataFrame.
# mezen has been added to the DataFrame.
# morondava has been added to the DataFrame.
# quixada has been added to the DataFrame.
# san cristobal has been added to the DataFrame.
# muroto has been added to the DataFrame.
# luderitz has been added to the DataFrame.
# tateyama has been added to the DataFrame.
# tidore has been added to the DataFrame.
# Missing City ... Skipping
# karatuzskoye has been added to the DataFrame.
# magdalena has been added to the DataFrame.
# esso has been added to the DataFrame.
# tupaciguara has been added to the DataFrame.
# skjervoy has been added to the DataFrame.
# koslan has been added to the DataFrame.
# aleksandrov gay has been added to the DataFrame.
# umm durman has been added to the DataFrame.
# Missing City ... Skipping
# suntar has been added to the DataFrame.
# grand gaube has been added to the DataFrame.
# sentyabrskiy has been added to the DataFrame.
# Missing City ... Skipping
# moyale has been added to the DataFrame.
# bam has been added to the DataFrame.
# zelenogorskiy has been added to the DataFrame.
# malanje has been added to the DataFrame.
# gorontalo has been added to the DataFrame.
# sahuaripa has been added to the DataFrame.
# broome has been added to the DataFrame.
# kiomboi has been added to the DataFrame.
# kodiak has been added to the DataFrame.
# tadine has been added to the DataFrame.
# bolungarvik has been added to the DataFrame.
# Missing City ... Skipping
# pati has been added to the DataFrame.
# pisco has been added to the DataFrame.
# kadoma has been added to the DataFrame.
# biak has been added to the DataFrame.
# tongzi has been added to the DataFrame.
# smithfield has been added to the DataFrame.
# jaisalmer has been added to the DataFrame.
# jatiroto has been added to the DataFrame.
# samarai has been added to the DataFrame.
# tiksi has been added to the DataFrame.
# praya has been added to the DataFrame.
# manokwari has been added to the DataFrame.
# lorengau has been added to the DataFrame.
# baiyin has been added to the DataFrame.
# toliary has been added to the DataFrame.
# Missing City ... Skipping
# karaul has been added to the DataFrame.
# Missing City ... Skipping
# ahipara has been added to the DataFrame.
# kushiro has been added to the DataFrame.
# kenai has been added to the DataFrame.
# sal rei has been added to the DataFrame.
# shelburne has been added to the DataFrame.
# sungurlu has been added to the DataFrame.
# marv dasht has been added to the DataFrame.
# Missing City ... Skipping
# belaya gora has been added to the DataFrame.
# urusha has been added to the DataFrame.
# vanimo has been added to the DataFrame.
# viligili has been added to the DataFrame.
# Missing City ... Skipping
# talnakh has been added to the DataFrame.
# tuatapere has been added to the DataFrame.
# sabang has been added to the DataFrame.
# houston has been added to the DataFrame.
# kisangani has been added to the DataFrame.
# tsihombe has been added to the DataFrame.
# Missing City ... Skipping
# alyangula has been added to the DataFrame.
# matara has been added to the DataFrame.
# tungor has been added to the DataFrame.
# mitu has been added to the DataFrame.
# maltahohe has been added to the DataFrame.
# baykit has been added to the DataFrame.
# lianran has been added to the DataFrame.
# guilin has been added to the DataFrame.
# crab hill has been added to the DataFrame.
# Missing City ... Skipping
# sarangani has been added to the DataFrame.
# broken hill has been added to the DataFrame.
# granada has been added to the DataFrame.
# longyearbyen has been added to the DataFrame.
# coetupo has been added to the DataFrame.
# Missing City ... Skipping
# monrovia has been added to the DataFrame.
# xichang has been added to the DataFrame.
# asau has been added to the DataFrame.
# kloulklubed has been added to the DataFrame.
# funadhoo has been added to the DataFrame.
# umm lajj has been added to the DataFrame.
# pochutla has been added to the DataFrame.
# ewa beach has been added to the DataFrame.
# filadelfia has been added to the DataFrame.
# tambul has been added to the DataFrame.
# Missing City ... Skipping
# san borja has been added to the DataFrame.
# zhangye has been added to the DataFrame.
# burnie has been added to the DataFrame.
# riohacha has been added to the DataFrame.
# gazanjyk has been added to the DataFrame.
# lata has been added to the DataFrame.
# sodertalje has been added to the DataFrame.
# Missing City ... Skipping
# ijaki has been added to the DataFrame.
# Missing City ... Skipping
# kayes has been added to the DataFrame.
# raudeberg has been added to the DataFrame.
# kismayo has been added to the DataFrame.
# puerto penasco has been added to the DataFrame.
# lagoa has been added to the DataFrame.
# silae has been added to the DataFrame.
# buzmeyin has been added to the DataFrame.
# palaiokhora has been added to the DataFrame.
# Missing City ... Skipping
# ha giang has been added to the DataFrame.
# chuy has been added to the DataFrame.
# yar-sale has been added to the DataFrame.
# faanui has been added to the DataFrame.
# atambua has been added to the DataFrame.
# bubaque has been added to the DataFrame.
# padang has been added to the DataFrame.
# kualakapuas has been added to the DataFrame.
# mahibadhoo has been added to the DataFrame.
# chagda has been added to the DataFrame.
# Missing City ... Skipping
# fukue has been added to the DataFrame.
# dukat has been added to the DataFrame.
# tura has been added to the DataFrame.
# qaqortoq has been added to the DataFrame.
# aitape has been added to the DataFrame.
# sept-iles has been added to the DataFrame.
# benguela has been added to the DataFrame.
# show low has been added to the DataFrame.
# vao has been added to the DataFrame.
# sweetwater has been added to the DataFrame.
# cayhagan has been added to the DataFrame.
# san felipe has been added to the DataFrame.
# hamilton has been added to the DataFrame.
# abu samrah has been added to the DataFrame.
# inirida has been added to the DataFrame.
# nelson bay has been added to the DataFrame.
# mulatupo has been added to the DataFrame.
# los llanos de aridane has been added to the DataFrame.
# podor has been added to the DataFrame.
# mahon has been added to the DataFrame.
# araouane has been added to the DataFrame.
# ketchikan has been added to the DataFrame.
# shenjiamen has been added to the DataFrame.
# tucuman has been added to the DataFrame.
# semporna has been added to the DataFrame.
# san has been added to the DataFrame.
# fortuna has been added to the DataFrame.
# kesova gora has been added to the DataFrame.
# lodja has been added to the DataFrame.
# chebsara has been added to the DataFrame.
# marathon has been added to the DataFrame.
# ust-nera has been added to the DataFrame.
# ancud has been added to the DataFrame.
# visnes has been added to the DataFrame.
# praia has been added to the DataFrame.
# woodward has been added to the DataFrame.
# ca mau has been added to the DataFrame.
# devils lake has been added to the DataFrame.
# mount isa has been added to the DataFrame.
# ixtapa has been added to the DataFrame.
# luis correia has been added to the DataFrame.
# timra has been added to the DataFrame.
# codrington has been added to the DataFrame.
# dresden has been added to the DataFrame.
# gladstone has been added to the DataFrame.
# morgan city has been added to the DataFrame.
# byron bay has been added to the DataFrame.
# bababe has been added to the DataFrame.
# Missing City ... Skipping
# rawlins has been added to the DataFrame.
# riyadh has been added to the DataFrame.
# raga has been added to the DataFrame.
# snasa has been added to the DataFrame.
# samusu has been added to the DataFrame.
# Missing City ... Skipping
# shitanjing has been added to the DataFrame.
# jinxiang has been added to the DataFrame.
# amapa has been added to the DataFrame.
# buraydah has been added to the DataFrame.
# mandera has been added to the DataFrame.
# fallon has been added to the DataFrame.
# tambo has been added to the DataFrame.
# durres has been added to the DataFrame.
# nanortalik has been added to the DataFrame.
# sao jose da coroa grande has been added to the DataFrame.
# mayskiy has been added to the DataFrame.
# engenheiro beltrao has been added to the DataFrame.
# nouakchott has been added to the DataFrame.
# san juan has been added to the DataFrame.
# bendigo has been added to the DataFrame.
# yaan has been added to the DataFrame.
# geraldton has been added to the DataFrame.
# andevoranto has been added to the DataFrame.
# Missing City ... Skipping
# beringovskiy has been added to the DataFrame.
# darnah has been added to the DataFrame.
# balabac has been added to the DataFrame.
# ribeira grande has been added to the DataFrame.
# guajara-mirim has been added to the DataFrame.
# Missing City ... Skipping
# uwayl has been added to the DataFrame.
# Missing City ... Skipping
# ratnagiri has been added to the DataFrame.
# sao joao da barra has been added to the DataFrame.
# lincoln has been added to the DataFrame.
# shimoda has been added to the DataFrame.
# trairi has been added to the DataFrame.
# klaksvik has been added to the DataFrame.
# anadyr has been added to the DataFrame.
# carballo has been added to the DataFrame.
# danilovka has been added to the DataFrame.
# candolim has been added to the DataFrame.
# aklavik has been added to the DataFrame.
# cap malheureux has been added to the DataFrame.
# swan river has been added to the DataFrame.
# sarh has been added to the DataFrame.
# vostok has been added to the DataFrame.
# mnogovershinnyy has been added to the DataFrame.
# mogadishu has been added to the DataFrame.
# salinas has been added to the DataFrame.
# rolim de moura has been added to the DataFrame.
# Missing City ... Skipping
# lac du bonnet has been added to the DataFrame.
# sibolga has been added to the DataFrame.
# pouembout has been added to the DataFrame.
# sovetskiy has been added to the DataFrame.
# southampton has been added to the DataFrame.
# cockburn town has been added to the DataFrame.
# vaasa has been added to the DataFrame.
# myitkyina has been added to the DataFrame.
# lujiang has been added to the DataFrame.
# tongren has been added to the DataFrame.
# marawi has been added to the DataFrame.
# ituni has been added to the DataFrame.
# Missing City ... Skipping
# cayenne has been added to the DataFrame.
# xuddur has been added to the DataFrame.
# huanren has been added to the DataFrame.
# yatou has been added to the DataFrame.
# goodyear has been added to the DataFrame.
# vanderhoof has been added to the DataFrame.
# mokolo has been added to the DataFrame.
# mackenzie has been added to the DataFrame.
# yinchuan has been added to the DataFrame.
# malinovoye ozero has been added to the DataFrame.
# shaoxing has been added to the DataFrame.
# gizo has been added to the DataFrame.
# lewiston has been added to the DataFrame.
# sciacca has been added to the DataFrame.
# rangapara has been added to the DataFrame.
# bintulu has been added to the DataFrame.
# ossora has been added to the DataFrame.
# bayan has been added to the DataFrame.
# clonakilty has been added to the DataFrame.
# fort saint john has been added to the DataFrame.
# Missing City ... Skipping
# marcona has been added to the DataFrame.
# Missing City ... Skipping
# aksarka has been added to the DataFrame.
# berlevag has been added to the DataFrame.
# narsaq has been added to the DataFrame.
# ginir has been added to the DataFrame.
# lima has been added to the DataFrame.
# palmer has been added to the DataFrame.
# lalomanu has been added to the DataFrame.
# Missing City ... Skipping
# narimanov has been added to the DataFrame.
# nong khai has been added to the DataFrame.
# strezhevoy has been added to the DataFrame.
# odweyne has been added to the DataFrame.
# lamu has been added to the DataFrame.
# cocorit has been added to the DataFrame.
# igarka has been added to the DataFrame.
# dhamtari has been added to the DataFrame.
# paita has been added to the DataFrame.
# murska sobota has been added to the DataFrame.
# hasaki has been added to the DataFrame.
# saint-leu has been added to the DataFrame.
# emporia has been added to the DataFrame.
# santa vitoria do palmar has been added to the DataFrame.
# trincomalee has been added to the DataFrame.
# mergui has been added to the DataFrame.
# Missing City ... Skipping
# carutapera has been added to the DataFrame.
# hami has been added to the DataFrame.
# erzin has been added to the DataFrame.
# saint anthony has been added to the DataFrame.
# moengo has been added to the DataFrame.
# nikolskoye has been added to the DataFrame.
# clyde river has been added to the DataFrame.
# saint-hubert has been added to the DataFrame.
# thompson has been added to the DataFrame.
# namie has been added to the DataFrame.
# inuvik has been added to the DataFrame.
# valladolid has been added to the DataFrame.
# hudson bay has been added to the DataFrame.
# dafeng has been added to the DataFrame.
# aksu has been added to the DataFrame.
# la libertad has been added to the DataFrame.
# roald has been added to the DataFrame.
# obo has been added to the DataFrame.
# comodoro rivadavia has been added to the DataFrame.
# am timan has been added to the DataFrame.
# kalmunai has been added to the DataFrame.
# khromtau has been added to the DataFrame.
# buta has been added to the DataFrame.
# batagay-alyta has been added to the DataFrame.
# viedma has been added to the DataFrame.
# kars has been added to the DataFrame.
# carauari has been added to the DataFrame.
# colesberg has been added to the DataFrame.
# la romana has been added to the DataFrame.
# touros has been added to the DataFrame.
# yelizovo has been added to the DataFrame.
# pangnirtung has been added to the DataFrame.
# mugur-aksy has been added to the DataFrame.
# brewster has been added to the DataFrame.
# naifaru has been added to the DataFrame.
# sorkjosen has been added to the DataFrame.
# rocha has been added to the DataFrame.
# andilamena has been added to the DataFrame.
# bratsk has been added to the DataFrame.
# kishi has been added to the DataFrame.
# nurota has been added to the DataFrame.
# sangin has been added to the DataFrame.
# margate has been added to the DataFrame.
# flinders has been added to the DataFrame.
# inta has been added to the DataFrame.
# dunedin has been added to the DataFrame.
# callaguip has been added to the DataFrame.
# port hardy has been added to the DataFrame.
# verkhoyansk has been added to the DataFrame.
# grindavik has been added to the DataFrame.
# rafai has been added to the DataFrame.
# piritiba has been added to the DataFrame.
# tabiauea has been added to the DataFrame.
# Missing City ... Skipping
# alofi has been added to the DataFrame.
# scarborough has been added to the DataFrame.
# madisonville has been added to the DataFrame.
# necochea has been added to the DataFrame.
# jutai has been added to the DataFrame.
# mangrol has been added to the DataFrame.
# rio cuarto has been added to the DataFrame.
# tahoua has been added to the DataFrame.
# tanggu has been added to the DataFrame.
# mount gambier has been added to the DataFrame.
# leh has been added to the DataFrame.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = df.replace('', np.nan)

# %%
cities_full = cities_df.dropna(axis = 0)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
cities_full.describe()
# Out:
#                Date         Lat         Lng    Max Temp    Humidity  \
# count  5.580000e+02  558.000000  558.000000  558.000000  558.000000
# mean   1.590242e+09   19.908513   23.676434   67.539964   65.888889
# std    6.003145e+01   32.763825   90.503685   17.453879   23.405761
# min    1.590242e+09  -54.800000 -175.200000   23.680000    5.000000
# 25%    1.590242e+09   -4.805000  -56.035000   55.400000   51.000000
# 50%    1.590242e+09   22.845000   26.925000   69.800000   71.000000
# 75%    1.590242e+09   46.475000  104.202500   80.992500   83.000000
# max    1.590242e+09   78.220000  179.320000  111.830000  100.000000
#
#        Cloudiness  Wind Speed
# count  558.000000  558.000000
# mean    52.629032    8.486810
# std     40.354538    5.922078
# min      0.000000    0.180000
# 25%      5.000000    4.000000
# 50%     61.000000    6.930000
# 75%     94.000000   11.577500
# max    100.000000   38.030000

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cities_clean = cities_full.loc[cities_full['Humidity']< 100]

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
cities_clean.to_csv('City_data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
from scipy import stats
import scipy.stats as st

x = cities_clean['Lat']
y = cities_clean['Max Temp']

plt.scatter(x,y, facecolors = 'orange', edgecolor = 'black')
plt.title('City Latitude vs. Max Temp (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.grid(b= True)
plt.savefig("Fig1.png")

#The temperature increases as you get closer to the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x = cities_clean['Lat']
y = cities_clean['Humidity']

plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.title('City Latitude vs. Humidity %')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.grid(b= True)
plt.savefig("Fig2.png")
#Humidity is consistently high around the equator and becomes more distributed as you move either north or south

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x = cities_clean['Lat']
y = cities_clean['Cloudiness']

plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.title('City Latitude vs. Cloudiness %')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.grid(b= True)
plt.savefig("Fig3.png")
#Majority of citys have either 100% cloudiness or very low-to-0 cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x = cities_clean['Lat']
y = cities_clean['Wind Speed']

plt.scatter(x,y, facecolors = 'green', edgecolor = 'black')
plt.title('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b= True)
plt.savefig("Fig4.png")
#Most observed cities do not have wind speed above 10 mph

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern = cities_clean.loc[cities_clean['Lat']>= 0]
southern = cities_clean.loc[cities_clean['Lat']< 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Max Temp']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig5.png")
# The high -r value indicates a strong negative correlation between latitude and max temperature.
# Out:
#  The r-squared is -0.7874549684814771

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Max Temp']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig6.png")
# The high r value indicates a strong positive correlation between latitude and max temperature.
# Out:
#  The r-squared is 0.7687204457293964

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Humidity']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig7.png")
#The low r values indicate a weak to no relationship between humidity and latitude.
# Out:
#  The r-squared is 0.025411365950933407

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Humidity']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig8.png")
# Out:
#  The r-squared is 0.11241592390602578

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Cloudiness']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig9.png")
#The low r values indicate a weak positive relationship between latitude and cloudiness.
# Out:
#  The r-squared is 0.0655851957446864

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Cloudiness']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig10.png")
# Out:
#  The r-squared is -0.0855310801249465

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Wind Speed']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("Fig11.png")
#The low r values indicate that there is no real relationship between wind speed and latitude. The difference 
#between the hemispheres doesn't seem to be significant enough to comment upon.
# Out:
#  The r-squared is 0.13685877745833103

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Wind Speed']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b= True)
plt.savefig("Fig12.png")
print(f' The r-squared is {cor[0]}')
# Out:
#  The r-squared is -0.10070114728200802
