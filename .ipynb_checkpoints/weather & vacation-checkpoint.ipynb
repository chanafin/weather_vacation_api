# %%
# Dependencies and Setup
# !pip install citipy
#!pip install gmaps
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import os
import time
from scipy.stats import linregress
import gmaps
import gmaps.datasets
# Import API key
from api_keys import weather_api_key
from api_keys import g_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for i in lat_lngs:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities

df = pd.DataFrame(cities)
df['Country'] = ''
df['Date'] = ''
df['Lat'] = ''
df['Lng'] = ''
df['Max Temp'] = ''
df['Humidity'] = ''
df['Cloudiness'] = ''
df['Wind Speed'] = ''
df.rename(columns = {0 : 'City'}, inplace = True)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
for index, row in df.iterrows():
    url = "http://api.openweathermap.org/data/2.5/weather?"
    city = row['City']
    response = requests.get(url + 'appid=' + weather_api_key + '&q=' + city + "&units=Imperial")
    response = response.json()
    try:
        print(f'{city} has been added to the DataFrame.')
        df.loc[index, 'Lat'] = response['coord']['lat']
        df.loc[index, 'Lng'] = response['coord']['lon']
        df.loc[index, 'Max Temp'] = response['main']['temp_max']
        df.loc[index, 'Humidity'] = response['main']['humidity']
        df.loc[index, 'Cloudiness'] = response['clouds']['all']
        df.loc[index, 'Wind Speed'] = response['wind']['speed']
        df.loc[index, 'Country'] = response['sys']['country']
        df.loc[index, 'Date'] = response['dt']
    except(KeyError, IndexError):
        print('Missing City ... Skipping')
# Out:
# lewisville has been added to the DataFrame.
# taolanaro has been added to the DataFrame.
# Missing City ... Skipping
# pinega has been added to the DataFrame.
# san cristobal has been added to the DataFrame.
# huacho has been added to the DataFrame.
# busselton has been added to the DataFrame.
# cortez has been added to the DataFrame.
# kushima has been added to the DataFrame.
# ambon has been added to the DataFrame.
# illoqqortoormiut has been added to the DataFrame.
# Missing City ... Skipping
# sibolga has been added to the DataFrame.
# bluff has been added to the DataFrame.
# barrow has been added to the DataFrame.
# qaanaaq has been added to the DataFrame.
# hamilton has been added to the DataFrame.
# mayumba has been added to the DataFrame.
# bengkulu has been added to the DataFrame.
# albany has been added to the DataFrame.
# manzanillo has been added to the DataFrame.
# prabumulih has been added to the DataFrame.
# ushuaia has been added to the DataFrame.
# east london has been added to the DataFrame.
# punta arenas has been added to the DataFrame.
# cabo san lucas has been added to the DataFrame.
# bulgan has been added to the DataFrame.
# lebu has been added to the DataFrame.
# saskylakh has been added to the DataFrame.
# atikokan has been added to the DataFrame.
# puerto ayora has been added to the DataFrame.
# castro has been added to the DataFrame.
# bredasdorp has been added to the DataFrame.
# kaeo has been added to the DataFrame.
# hithadhoo has been added to the DataFrame.
# ancud has been added to the DataFrame.
# mongo has been added to the DataFrame.
# hermanus has been added to the DataFrame.
# mys shmidta has been added to the DataFrame.
# Missing City ... Skipping
# mataura has been added to the DataFrame.
# rikitea has been added to the DataFrame.
# alugan has been added to the DataFrame.
# cape town has been added to the DataFrame.
# north branch has been added to the DataFrame.
# mackenzie has been added to the DataFrame.
# mogadishu has been added to the DataFrame.
# hokitika has been added to the DataFrame.
# saldanha has been added to the DataFrame.
# fortuna has been added to the DataFrame.
# gamba has been added to the DataFrame.
# petropavlovsk-kamchatskiy has been added to the DataFrame.
# dolores has been added to the DataFrame.
# kavaratti has been added to the DataFrame.
# teya has been added to the DataFrame.
# pevek has been added to the DataFrame.
# chapais has been added to the DataFrame.
# onguday has been added to the DataFrame.
# yellowknife has been added to the DataFrame.
# lorengau has been added to the DataFrame.
# kruisfontein has been added to the DataFrame.
# ribeira grande has been added to the DataFrame.
# lamballe has been added to the DataFrame.
# sulangan has been added to the DataFrame.
# saint-philippe has been added to the DataFrame.
# piacabucu has been added to the DataFrame.
# tasiilaq has been added to the DataFrame.
# boyolangu has been added to the DataFrame.
# luderitz has been added to the DataFrame.
# duz has been added to the DataFrame.
# Missing City ... Skipping
# dhaka has been added to the DataFrame.
# santiago del estero has been added to the DataFrame.
# paka has been added to the DataFrame.
# dispur has been added to the DataFrame.
# alexandria has been added to the DataFrame.
# viedma has been added to the DataFrame.
# mar del plata has been added to the DataFrame.
# leningradskiy has been added to the DataFrame.
# mutum has been added to the DataFrame.
# ugoofaaru has been added to the DataFrame.
# guerrero negro has been added to the DataFrame.
# ossora has been added to the DataFrame.
# codrington has been added to the DataFrame.
# russell has been added to the DataFrame.
# lazaro cardenas has been added to the DataFrame.
# talnakh has been added to the DataFrame.
# hobart has been added to the DataFrame.
# shingu has been added to the DataFrame.
# ondangwa has been added to the DataFrame.
# tessalit has been added to the DataFrame.
# belushya guba has been added to the DataFrame.
# Missing City ... Skipping
# victoria has been added to the DataFrame.
# port elizabeth has been added to the DataFrame.
# ayagoz has been added to the DataFrame.
# mercedes has been added to the DataFrame.
# dikson has been added to the DataFrame.
# arraial do cabo has been added to the DataFrame.
# llanes has been added to the DataFrame.
# mareeba has been added to the DataFrame.
# new norfolk has been added to the DataFrame.
# laguna has been added to the DataFrame.
# canchungo has been added to the DataFrame.
# esperance has been added to the DataFrame.
# mumford has been added to the DataFrame.
# provideniya has been added to the DataFrame.
# nikolskoye has been added to the DataFrame.
# longyearbyen has been added to the DataFrame.
# lata has been added to the DataFrame.
# ponta do sol has been added to the DataFrame.
# samusu has been added to the DataFrame.
# Missing City ... Skipping
# avarua has been added to the DataFrame.
# eureka has been added to the DataFrame.
# vitim has been added to the DataFrame.
# mahebourg has been added to the DataFrame.
# ostrovnoy has been added to the DataFrame.
# the pas has been added to the DataFrame.
# ixtapa has been added to the DataFrame.
# sao filipe has been added to the DataFrame.
# port alfred has been added to the DataFrame.
# batemans bay has been added to the DataFrame.
# bolshaya dzhalga has been added to the DataFrame.
# bethel has been added to the DataFrame.
# lavrentiya has been added to the DataFrame.
# seydi has been added to the DataFrame.
# naze has been added to the DataFrame.
# aitape has been added to the DataFrame.
# uige has been added to the DataFrame.
# faanui has been added to the DataFrame.
# binzhou has been added to the DataFrame.
# chara has been added to the DataFrame.
# kodiak has been added to the DataFrame.
# aklavik has been added to the DataFrame.
# gillette has been added to the DataFrame.
# touros has been added to the DataFrame.
# berdigestyakh has been added to the DataFrame.
# cherskiy has been added to the DataFrame.
# kapaa has been added to the DataFrame.
# diamantino has been added to the DataFrame.
# padang has been added to the DataFrame.
# klaksvik has been added to the DataFrame.
# karratha has been added to the DataFrame.
# beringovskiy has been added to the DataFrame.
# bambous virieux has been added to the DataFrame.
# de-kastri has been added to the DataFrame.
# sitka has been added to the DataFrame.
# mackay has been added to the DataFrame.
# mendi has been added to the DataFrame.
# saint george has been added to the DataFrame.
# jamestown has been added to the DataFrame.
# awjilah has been added to the DataFrame.
# tambo has been added to the DataFrame.
# cidreira has been added to the DataFrame.
# nanortalik has been added to the DataFrame.
# vila velha has been added to the DataFrame.
# tuatapere has been added to the DataFrame.
# bilma has been added to the DataFrame.
# lasa has been added to the DataFrame.
# khatanga has been added to the DataFrame.
# stoyba has been added to the DataFrame.
# Missing City ... Skipping
# ahuimanu has been added to the DataFrame.
# patacamaya has been added to the DataFrame.
# upernavik has been added to the DataFrame.
# belmonte has been added to the DataFrame.
# arman has been added to the DataFrame.
# hervey bay has been added to the DataFrame.
# butaritari has been added to the DataFrame.
# portland has been added to the DataFrame.
# lipari has been added to the DataFrame.
# vaini has been added to the DataFrame.
# atuona has been added to the DataFrame.
# tala has been added to the DataFrame.
# hit has been added to the DataFrame.
# northam has been added to the DataFrame.
# thompson has been added to the DataFrame.
# athens has been added to the DataFrame.
# chuy has been added to the DataFrame.
# jishou has been added to the DataFrame.
# tagusao has been added to the DataFrame.
# norman wells has been added to the DataFrame.
# georgetown has been added to the DataFrame.
# kamenskoye has been added to the DataFrame.
# Missing City ... Skipping
# pangoa has been added to the DataFrame.
# araripina has been added to the DataFrame.
# secunda has been added to the DataFrame.
# hilo has been added to the DataFrame.
# akbarpur has been added to the DataFrame.
# krasnyy chikoy has been added to the DataFrame.
# mwene-ditu has been added to the DataFrame.
# atambua has been added to the DataFrame.
# saint-louis has been added to the DataFrame.
# saint-pierre has been added to the DataFrame.
# darnah has been added to the DataFrame.
# nome has been added to the DataFrame.
# maroantsetra has been added to the DataFrame.
# palabuhanratu has been added to the DataFrame.
# Missing City ... Skipping
# atasu has been added to the DataFrame.
# carroll has been added to the DataFrame.
# barrhead has been added to the DataFrame.
# beloha has been added to the DataFrame.
# ngukurr has been added to the DataFrame.
# Missing City ... Skipping
# ayorou has been added to the DataFrame.
# constitucion has been added to the DataFrame.
# bonavista has been added to the DataFrame.
# alta floresta has been added to the DataFrame.
# pochutla has been added to the DataFrame.
# zaysan has been added to the DataFrame.
# kota kinabalu has been added to the DataFrame.
# valreas has been added to the DataFrame.
# correntina has been added to the DataFrame.
# ahipara has been added to the DataFrame.
# buritis has been added to the DataFrame.
# adrar has been added to the DataFrame.
# batagay-alyta has been added to the DataFrame.
# geraldton has been added to the DataFrame.
# kaitangata has been added to the DataFrame.
# krasnoselkup has been added to the DataFrame.
# sisimiut has been added to the DataFrame.
# teguldet has been added to the DataFrame.
# santa isabel do rio negro has been added to the DataFrame.
# vredendal has been added to the DataFrame.
# port hardy has been added to the DataFrame.
# panlaitan has been added to the DataFrame.
# souillac has been added to the DataFrame.
# port lincoln has been added to the DataFrame.
# taoudenni has been added to the DataFrame.
# comodoro rivadavia has been added to the DataFrame.
# mehamn has been added to the DataFrame.
# merauke has been added to the DataFrame.
# pithiviers has been added to the DataFrame.
# los llanos de aridane has been added to the DataFrame.
# klyuchi has been added to the DataFrame.
# okhotsk has been added to the DataFrame.
# mettur has been added to the DataFrame.
# san jorge has been added to the DataFrame.
# amderma has been added to the DataFrame.
# Missing City ... Skipping
# mae sai has been added to the DataFrame.
# katima mulilo has been added to the DataFrame.
# bolungarvik has been added to the DataFrame.
# Missing City ... Skipping
# florence has been added to the DataFrame.
# muisne has been added to the DataFrame.
# bloemfontein has been added to the DataFrame.
# iberia has been added to the DataFrame.
# rundu has been added to the DataFrame.
# torbay has been added to the DataFrame.
# ust-kut has been added to the DataFrame.
# pag has been added to the DataFrame.
# narsaq has been added to the DataFrame.
# kifri has been added to the DataFrame.
# carmen has been added to the DataFrame.
# grand river south east has been added to the DataFrame.
# Missing City ... Skipping
# alice springs has been added to the DataFrame.
# saint-francois has been added to the DataFrame.
# neuquen has been added to the DataFrame.
# kharan has been added to the DataFrame.
# meyungs has been added to the DataFrame.
# Missing City ... Skipping
# tsihombe has been added to the DataFrame.
# Missing City ... Skipping
# lagoa has been added to the DataFrame.
# mount gambier has been added to the DataFrame.
# vestmannaeyjar has been added to the DataFrame.
# palmer has been added to the DataFrame.
# wamba has been added to the DataFrame.
# pavlovsk has been added to the DataFrame.
# svetlaya has been added to the DataFrame.
# synya has been added to the DataFrame.
# antofagasta has been added to the DataFrame.
# tuktoyaktuk has been added to the DataFrame.
# ciudad bolivar has been added to the DataFrame.
# belaya gora has been added to the DataFrame.
# attawapiskat has been added to the DataFrame.
# Missing City ... Skipping
# zamosc has been added to the DataFrame.
# buraydah has been added to the DataFrame.
# kang has been added to the DataFrame.
# el alto has been added to the DataFrame.
# astoria has been added to the DataFrame.
# vallenar has been added to the DataFrame.
# bani walid has been added to the DataFrame.
# grindavik has been added to the DataFrame.
# barentsburg has been added to the DataFrame.
# Missing City ... Skipping
# hasaki has been added to the DataFrame.
# jiwani has been added to the DataFrame.
# ereymentau has been added to the DataFrame.
# carnarvon has been added to the DataFrame.
# muros has been added to the DataFrame.
# boone has been added to the DataFrame.
# kisangani has been added to the DataFrame.
# ishigaki has been added to the DataFrame.
# desbiens has been added to the DataFrame.
# zhigansk has been added to the DataFrame.
# rungata has been added to the DataFrame.
# Missing City ... Skipping
# trofors has been added to the DataFrame.
# tumannyy has been added to the DataFrame.
# Missing City ... Skipping
# nemuro has been added to the DataFrame.
# elban has been added to the DataFrame.
# natal has been added to the DataFrame.
# tadine has been added to the DataFrame.
# te anau has been added to the DataFrame.
# sinnamary has been added to the DataFrame.
# birjand has been added to the DataFrame.
# vao has been added to the DataFrame.
# saint-georges has been added to the DataFrame.
# fairbanks has been added to the DataFrame.
# namibe has been added to the DataFrame.
# nyurba has been added to the DataFrame.
# bayanday has been added to the DataFrame.
# mandalgovi has been added to the DataFrame.
# avondale has been added to the DataFrame.
# salalah has been added to the DataFrame.
# kirakira has been added to the DataFrame.
# zhanatas has been added to the DataFrame.
# Missing City ... Skipping
# inta has been added to the DataFrame.
# asau has been added to the DataFrame.
# sabzevar has been added to the DataFrame.
# cockburn town has been added to the DataFrame.
# sena madureira has been added to the DataFrame.
# brigantine has been added to the DataFrame.
# guacheta has been added to the DataFrame.
# alto araguaia has been added to the DataFrame.
# tarata has been added to the DataFrame.
# thomasville has been added to the DataFrame.
# mattawa has been added to the DataFrame.
# pergamino has been added to the DataFrame.
# flin flon has been added to the DataFrame.
# iqaluit has been added to the DataFrame.
# naron has been added to the DataFrame.
# half moon bay has been added to the DataFrame.
# haines junction has been added to the DataFrame.
# sarankhola has been added to the DataFrame.
# dingle has been added to the DataFrame.
# zambezi has been added to the DataFrame.
# vardo has been added to the DataFrame.
# goure has been added to the DataFrame.
# baruun-urt has been added to the DataFrame.
# bandarbeyla has been added to the DataFrame.
# rognan has been added to the DataFrame.
# saint-esteve has been added to the DataFrame.
# pahalgam has been added to the DataFrame.
# selu has been added to the DataFrame.
# kudahuvadhoo has been added to the DataFrame.
# itarema has been added to the DataFrame.
# coahuayana has been added to the DataFrame.
# migori has been added to the DataFrame.
# smolenka has been added to the DataFrame.
# fria has been added to the DataFrame.
# port shepstone has been added to the DataFrame.
# kyzyl-suu has been added to the DataFrame.
# sechura has been added to the DataFrame.
# sentyabrskiy has been added to the DataFrame.
# Missing City ... Skipping
# moyale has been added to the DataFrame.
# roald has been added to the DataFrame.
# bull savanna has been added to the DataFrame.
# bonthe has been added to the DataFrame.
# guabito has been added to the DataFrame.
# tamworth has been added to the DataFrame.
# lucelia has been added to the DataFrame.
# caravelas has been added to the DataFrame.
# carbonia has been added to the DataFrame.
# port-gentil has been added to the DataFrame.
# hrodna has been added to the DataFrame.
# luena has been added to the DataFrame.
# wollongong has been added to the DataFrame.
# ureki has been added to the DataFrame.
# college has been added to the DataFrame.
# hoa binh has been added to the DataFrame.
# samalaeulu has been added to the DataFrame.
# Missing City ... Skipping
# celestun has been added to the DataFrame.
# clyde river has been added to the DataFrame.
# jawhar has been added to the DataFrame.
# faya has been added to the DataFrame.
# anadyr has been added to the DataFrame.
# awbari has been added to the DataFrame.
# san vicente has been added to the DataFrame.
# mudyuga has been added to the DataFrame.
# Missing City ... Skipping
# palasa has been added to the DataFrame.
# santa vitoria do palmar has been added to the DataFrame.
# torres has been added to the DataFrame.
# mahon has been added to the DataFrame.
# vila has been added to the DataFrame.
# volot has been added to the DataFrame.
# vaitupu has been added to the DataFrame.
# Missing City ... Skipping
# manado has been added to the DataFrame.
# warqla has been added to the DataFrame.
# Missing City ... Skipping
# umzimvubu has been added to the DataFrame.
# Missing City ... Skipping
# sofikon has been added to the DataFrame.
# piryetos has been added to the DataFrame.
# Missing City ... Skipping
# harper has been added to the DataFrame.
# tabiauea has been added to the DataFrame.
# Missing City ... Skipping
# ambodifototra has been added to the DataFrame.
# Missing City ... Skipping
# salmon arm has been added to the DataFrame.
# punta alta has been added to the DataFrame.
# kahului has been added to the DataFrame.
# deep river has been added to the DataFrame.
# severo-kurilsk has been added to the DataFrame.
# alvorada has been added to the DataFrame.
# bunbury has been added to the DataFrame.
# marzuq has been added to the DataFrame.
# poum has been added to the DataFrame.
# melito di porto salvo has been added to the DataFrame.
# roma has been added to the DataFrame.
# churapcha has been added to the DataFrame.
# concepcion del oro has been added to the DataFrame.
# chernenko has been added to the DataFrame.
# zhireken has been added to the DataFrame.
# kangasala has been added to the DataFrame.
# amursk has been added to the DataFrame.
# xining has been added to the DataFrame.
# capreol has been added to the DataFrame.
# simimbaan has been added to the DataFrame.
# biloela has been added to the DataFrame.
# manokwari has been added to the DataFrame.
# chinhoyi has been added to the DataFrame.
# chkalovskoye has been added to the DataFrame.
# abu samrah has been added to the DataFrame.
# tshikapa has been added to the DataFrame.
# plainview has been added to the DataFrame.
# matay has been added to the DataFrame.
# garissa has been added to the DataFrame.
# kalmunai has been added to the DataFrame.
# rumphi has been added to the DataFrame.
# pangody has been added to the DataFrame.
# kloulklubed has been added to the DataFrame.
# moron has been added to the DataFrame.
# montepuez has been added to the DataFrame.
# taganak has been added to the DataFrame.
# cukai has been added to the DataFrame.
# toledo has been added to the DataFrame.
# aquidauana has been added to the DataFrame.
# rawson has been added to the DataFrame.
# kjollefjord has been added to the DataFrame.
# sabang has been added to the DataFrame.
# turukhansk has been added to the DataFrame.
# diapaga has been added to the DataFrame.
# almeirim has been added to the DataFrame.
# hami has been added to the DataFrame.
# kavieng has been added to the DataFrame.
# labuhan has been added to the DataFrame.
# micheweni has been added to the DataFrame.
# nampula has been added to the DataFrame.
# bailieborough has been added to the DataFrame.
# acapulco has been added to the DataFrame.
# sumbawa has been added to the DataFrame.
# Missing City ... Skipping
# oarai has been added to the DataFrame.
# monrovia has been added to the DataFrame.
# walla walla has been added to the DataFrame.
# verkhnevilyuysk has been added to the DataFrame.
# riyadh has been added to the DataFrame.
# cabedelo has been added to the DataFrame.
# husavik has been added to the DataFrame.
# kupang has been added to the DataFrame.
# maarianhamina has been added to the DataFrame.
# berbera has been added to the DataFrame.
# santa cruz has been added to the DataFrame.
# kinloss has been added to the DataFrame.
# tura has been added to the DataFrame.
# malwan has been added to the DataFrame.
# Missing City ... Skipping
# tiznit has been added to the DataFrame.
# lithakia has been added to the DataFrame.
# katsuura has been added to the DataFrame.
# veraval has been added to the DataFrame.
# mullaitivu has been added to the DataFrame.
# Missing City ... Skipping
# nam tha has been added to the DataFrame.
# Missing City ... Skipping
# vanderhoof has been added to the DataFrame.
# chake chake has been added to the DataFrame.
# safford has been added to the DataFrame.
# tabas has been added to the DataFrame.
# westport has been added to the DataFrame.
# camacha has been added to the DataFrame.
# jacareacanga has been added to the DataFrame.
# vila franca do campo has been added to the DataFrame.
# dunedin has been added to the DataFrame.
# grand gaube has been added to the DataFrame.
# carbondale has been added to the DataFrame.
# muzquiz has been added to the DataFrame.
# Missing City ... Skipping
# avera has been added to the DataFrame.
# inderborskiy has been added to the DataFrame.
# Missing City ... Skipping
# libreville has been added to the DataFrame.
# verkhoyansk has been added to the DataFrame.
# shumskiy has been added to the DataFrame.
# hudiksvall has been added to the DataFrame.
# mariental has been added to the DataFrame.
# qandala has been added to the DataFrame.
# jinxiang has been added to the DataFrame.
# sur has been added to the DataFrame.
# liaozhong has been added to the DataFrame.
# barranca has been added to the DataFrame.
# suntar has been added to the DataFrame.
# yurga has been added to the DataFrame.
# puerto del rosario has been added to the DataFrame.
# nioro has been added to the DataFrame.
# broken hill has been added to the DataFrame.
# ozernovskiy has been added to the DataFrame.
# saryshagan has been added to the DataFrame.
# Missing City ... Skipping
# pauini has been added to the DataFrame.
# udachnyy has been added to the DataFrame.
# santa eulalia del rio has been added to the DataFrame.
# Missing City ... Skipping
# yialos has been added to the DataFrame.
# Missing City ... Skipping
# opobo has been added to the DataFrame.
# Missing City ... Skipping
# hambantota has been added to the DataFrame.
# altay has been added to the DataFrame.
# nguiu has been added to the DataFrame.
# Missing City ... Skipping
# tecpan has been added to the DataFrame.
# sampit has been added to the DataFrame.
# nouadhibou has been added to the DataFrame.
# curup has been added to the DataFrame.
# chunskiy has been added to the DataFrame.
# pangai has been added to the DataFrame.
# andenes has been added to the DataFrame.
# luang prabang has been added to the DataFrame.
# urzhum has been added to the DataFrame.
# bathsheba has been added to the DataFrame.
# de aar has been added to the DataFrame.
# puerto caimito has been added to the DataFrame.
# yemelyanovo has been added to the DataFrame.
# sao felix do xingu has been added to the DataFrame.
# malmo has been added to the DataFrame.
# sakaiminato has been added to the DataFrame.
# togur has been added to the DataFrame.
# channel-port aux basques has been added to the DataFrame.
# henties bay has been added to the DataFrame.
# santa rosa has been added to the DataFrame.
# nazarovo has been added to the DataFrame.
# catamarca has been added to the DataFrame.
# tiksi has been added to the DataFrame.
# whitehorse has been added to the DataFrame.
# condado has been added to the DataFrame.
# dawei has been added to the DataFrame.
# gizo has been added to the DataFrame.
# asten has been added to the DataFrame.
# san patricio has been added to the DataFrame.
# lokachi has been added to the DataFrame.
# the valley has been added to the DataFrame.
# broome has been added to the DataFrame.
# nantucket has been added to the DataFrame.
# tautira has been added to the DataFrame.
# mandan has been added to the DataFrame.
# manavalakurichi has been added to the DataFrame.
# erenhot has been added to the DataFrame.
# bokoro has been added to the DataFrame.
# asosa has been added to the DataFrame.
# newport has been added to the DataFrame.
# kodinsk has been added to the DataFrame.
# srednekolymsk has been added to the DataFrame.
# sinegorye has been added to the DataFrame.
# stepnyak has been added to the DataFrame.
# nizhneyansk has been added to the DataFrame.
# Missing City ... Skipping
# hohhot has been added to the DataFrame.
# ozorkow has been added to the DataFrame.
# tanjong karang has been added to the DataFrame.
# Missing City ... Skipping
# ulladulla has been added to the DataFrame.
# yoichi has been added to the DataFrame.
# brae has been added to the DataFrame.
# boa vista has been added to the DataFrame.
# kokino has been added to the DataFrame.
# olafsvik has been added to the DataFrame.
# lolua has been added to the DataFrame.
# Missing City ... Skipping
# bozeman has been added to the DataFrame.
# chokurdakh has been added to the DataFrame.
# leirvik has been added to the DataFrame.
# maua has been added to the DataFrame.
# tasbuget has been added to the DataFrame.
# Missing City ... Skipping
# semporna has been added to the DataFrame.
# louisbourg has been added to the DataFrame.
# Missing City ... Skipping
# coihaique has been added to the DataFrame.
# hovd has been added to the DataFrame.
# kilembe has been added to the DataFrame.
# lhokseumawe has been added to the DataFrame.
# thunder bay has been added to the DataFrame.
# surgut has been added to the DataFrame.
# ouesso has been added to the DataFrame.
# iquitos has been added to the DataFrame.
# kolchugino has been added to the DataFrame.
# korfez has been added to the DataFrame.
# jurado has been added to the DataFrame.
# plettenberg bay has been added to the DataFrame.
# kidal has been added to the DataFrame.
# gimli has been added to the DataFrame.
# hofn has been added to the DataFrame.
# sao jose da coroa grande has been added to the DataFrame.
# evensk has been added to the DataFrame.
# forst has been added to the DataFrame.
# banda aceh has been added to the DataFrame.
# port-cartier has been added to the DataFrame.
# concepcion del uruguay has been added to the DataFrame.
# myaundzha has been added to the DataFrame.
# kalanguy has been added to the DataFrame.
# maragua has been added to the DataFrame.
# yueyang has been added to the DataFrame.
# lompoc has been added to the DataFrame.
# ilulissat has been added to the DataFrame.
# tambovka has been added to the DataFrame.
# san jose has been added to the DataFrame.
# hirado has been added to the DataFrame.
# nicoya has been added to the DataFrame.
# kualakapuas has been added to the DataFrame.
# abu kamal has been added to the DataFrame.
# pisco has been added to the DataFrame.
# tazmalt has been added to the DataFrame.
# airai has been added to the DataFrame.
# muncie has been added to the DataFrame.
# lincoln has been added to the DataFrame.
# karpathos has been added to the DataFrame.
# urengoy has been added to the DataFrame.
# ambilobe has been added to the DataFrame.
# treinta y tres has been added to the DataFrame.
# cururupu has been added to the DataFrame.
# linjiang has been added to the DataFrame.
# sterling has been added to the DataFrame.
# bereda has been added to the DataFrame.
# shaowu has been added to the DataFrame.
# nipawin has been added to the DataFrame.
# baykit has been added to the DataFrame.
# miles city has been added to the DataFrame.
# bandar-e torkaman has been added to the DataFrame.
# Missing City ... Skipping
# pennagaram has been added to the DataFrame.
# ambagarh chauki has been added to the DataFrame.
# shangqiu has been added to the DataFrame.
# beberibe has been added to the DataFrame.
# bur gabo has been added to the DataFrame.
# Missing City ... Skipping
# sambava has been added to the DataFrame.
# kamaishi has been added to the DataFrame.
# vondrozo has been added to the DataFrame.
# shenjiamen has been added to the DataFrame.
# babushkin has been added to the DataFrame.
# sola has been added to the DataFrame.
# makakilo city has been added to the DataFrame.
# manta has been added to the DataFrame.
# bakchar has been added to the DataFrame.
# bitung has been added to the DataFrame.
# tefe has been added to the DataFrame.
# salinopolis has been added to the DataFrame.
# goderich has been added to the DataFrame.
# lake havasu city has been added to the DataFrame.
# reforma has been added to the DataFrame.
# chaplygin has been added to the DataFrame.
# peruibe has been added to the DataFrame.
# khasan has been added to the DataFrame.
# morondava has been added to the DataFrame.
# port blair has been added to the DataFrame.
# triesen has been added to the DataFrame.
# xuzhou has been added to the DataFrame.
# hagenow has been added to the DataFrame.
# assiniboia has been added to the DataFrame.

# %%
cities = df.replace('', np.nan)
cities = cities.dropna(axis = 0)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity = cities.loc[cities['Humidity'] >= 100]
humidity
# Out:
#                           City Country          Date    Lat     Lng  Max Temp  \
# 48   petropavlovsk-kamchatskiy      RU  1.601927e+09  53.05  158.65     46.40
# 70                      dispur      IN  1.601927e+09  26.14   91.79     82.40
# 98                   canchungo      GW  1.601927e+09  12.07  -16.03     75.20
# 99                   esperance      AU  1.601927e+09 -33.87  121.90     44.60
# 136                   klaksvik      FO  1.601927e+09  62.23   -6.59     50.00
# 153                       lasa      IT  1.601927e+09  46.62   10.70     52.00
# 217                 port hardy      CA  1.601927e+09  50.70 -127.42     53.60
# 232                    mae sai      TH  1.601927e+09  20.43   99.88     75.99
# 247              alice springs      AU  1.601927e+09 -23.70  133.88     50.00
# 254              mount gambier      AU  1.601927e+09 -37.83  140.77     41.00
# 262                tuktoyaktuk      CA  1.601927e+09  69.45 -133.04     35.60
# 326                      vardo      NO  1.601927e+09  70.37   31.11     42.80
# 353                port-gentil      GA  1.601927e+09  -0.72    8.78     77.00
# 376                     manado      ID  1.601927e+09   1.49  124.85     73.40
# 419                    taganak      PH  1.601927e+09   6.08  118.30     77.00
# 445              maarianhamina      AX  1.601927e+09  60.10   19.93     53.60
# 544                  ulladulla      AU  1.601927e+09 -35.35  150.47     55.99
# 603                     bereda      ES  1.601927e+09  43.27   -7.54     64.00
# 616                   vondrozo      MG  1.601927e+09 -22.82   47.28     56.01
# 623                     bitung      ID  1.601927e+09   1.45  125.18     73.40
#
#      Humidity  Cloudiness  Wind Speed
# 48      100.0        90.0        6.71
# 70      100.0        75.0        2.24
# 98      100.0        90.0        2.24
# 99      100.0        40.0        3.36
# 136     100.0        92.0       11.41
# 153     100.0        40.0        4.70
# 217     100.0        90.0        5.82
# 232     100.0        40.0        3.36
# 247     100.0        90.0        8.05
# 254     100.0        90.0        5.82
# 262     100.0        90.0       14.99
# 326     100.0        90.0        9.17
# 353     100.0        90.0       14.99
# 376     100.0        40.0        2.24
# 419     100.0        20.0        1.12
# 445     100.0         0.0        4.70
# 544     100.0        90.0        5.82
# 603     100.0       100.0        7.00
# 616     100.0        99.0        4.70
# 623     100.0        40.0        2.24

# %%
# Make a new DataFrame equal to the city data to drop all humidity outlier
cities = cities.loc[cities['Humidity']< 100]

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
cities.to_csv('output/city_data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
from scipy import stats
import scipy.stats as st

x = cities['Lat']
y = cities['Max Temp']

plt.scatter(x,y, facecolors = 'orange', edgecolor = 'black')
plt.title('City Latitude vs. Max Temp (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.grid(b= True)
plt.savefig("output/figures/lat_temp.png")

#The temperature increases as you get closer to the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x = cities['Lat']
y = cities['Humidity']

plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.title('City Latitude vs. Humidity %')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.grid(b= True)
plt.savefig("output/figures/lat_humidity.png")
#Humidity is consistently high around the equator and becomes more distributed as you move either north or south

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x = cities['Lat']
y = cities['Cloudiness']

plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.title('City Latitude vs. Cloudiness %')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.grid(b= True)
plt.savefig("output/figures/lat_clouds.png")
#Majority of citys have either 100% cloudiness or very low-to-0 cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x = cities['Lat']
y = cities['Wind Speed']

plt.scatter(x,y, facecolors = 'green', edgecolor = 'black')
plt.title('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b= True)
plt.savefig("output/figures/lat_wind.png")
#Most observed cities do not have wind speed above 10 mph

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern = cities.loc[cities['Lat']>= 0]
southern = cities.loc[cities['Lat']< 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Max Temp']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/north_lat_temp.png")
# The high -r value indicates a strong negative correlation between latitude and max temperature.
# Out:
#  The r-squared is -0.8264615900420769

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Max Temp']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/south_lat_temp.png")
# The high r value indicates a strong positive correlation between latitude and max temperature.
# Out:
#  The r-squared is 0.6498392363324106

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Humidity']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/north_lat_humidity.png")
#The low r values indicate a weak to no relationship between humidity and latitude.
# Out:
#  The r-squared is 0.23096660464857824

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Humidity']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/south_lat_humidity.png")
# Out:
#  The r-squared is 0.007711137561062979

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Cloudiness']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/north_lat_clouds.png")
#The low r values indicate a weak positive relationship between latitude and cloudiness.
# Out:
#  The r-squared is 0.12594504352775468

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Cloudiness']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/south_lat_clouds.png")
# Out:
#  The r-squared is 0.12652559660032914

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern['Lat']
y = northern['Wind Speed']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'blue', edgecolor = 'black')
plt.plot(x, line, color = 'red')
plt.title('Northern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b= True)
print(f' The r-squared is {cor[0]}')
plt.savefig("output/figures/north_lat_wind.png")
#The low r values indicate that there is no real relationship between wind speed and latitude. The difference 
#between the hemispheres doesn't seem to be significant enough to comment upon.
# Out:
#  The r-squared is 0.04342818033602777

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern['Lat']
y = southern['Wind Speed']
(slope, intercept, pvalue, rvalue, stderr) = stats.linregress(x,y)
line = slope * x + intercept
cor = st.pearsonr(x,y)
plt.scatter(x,y, facecolors = 'red', edgecolor = 'black')
plt.plot(x, line, color = 'blue')
plt.title('Southern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(b= True)
plt.savefig("output/figures/south_lat_wind.png")
print(f' The r-squared is {cor[0]}')
# Out:
#  The r-squared is -0.19638633967708025

# %%
#Load the CSV previously exported into DataFrame
data = "output/city_data.csv"
cities = pd.read_csv(data)
cities.rename(columns = {'Unnamed: 0' : 'Drop'}, inplace = True)
del cities['Drop']
#
cities
# Out:
#               City Country          Date    Lat     Lng  Max Temp  Humidity  \
# 0       lewisville      US  1.601927e+09  33.05  -96.99     79.00      46.0
# 1           pinega      RU  1.601927e+09  64.70   43.39     39.88      95.0
# 2    san cristobal      VE  1.601927e+09   7.77  -72.22     75.99      77.0
# 3           huacho      PE  1.601927e+09 -11.11  -77.61     66.45      66.0
# 4        busselton      AU  1.601927e+09 -33.65  115.33     48.99      55.0
# ..             ...     ...           ...    ...     ...       ...       ...
# 566     port blair      IN  1.601927e+09  11.67   92.75     80.65      85.0
# 567        triesen      LI  1.601927e+09  47.10    9.53     52.00      93.0
# 568         xuzhou      CN  1.601927e+09  34.18  117.16     53.38      44.0
# 569        hagenow      DE  1.601927e+09  53.43   11.18     50.00      95.0
# 570     assiniboia      CA  1.601927e+09  49.63 -105.98     64.33      31.0
#
#      Cloudiness  Wind Speed
# 0           0.0        1.99
# 1          13.0        1.74
# 2          97.0        4.94
# 3           2.0        7.72
# 4          99.0        8.19
# ..          ...         ...
# 566        25.0        7.67
# 567        90.0        1.99
# 568        55.0        4.36
# 569       100.0        1.99
# 570         0.0       17.49
#
# [571 rows x 9 columns]

# %%
#Create a Humidity map using gmaps that uses Latitude and Longitude as the location 
#and add the Humidity as a Layer Heatmap 
# !jupyter nbextension list
# !jupyter nbextension enable --py gmaps
from ipywidgets.embed import embed_minimal_html
#
gmaps.configure(api_key = g_key)
locations = cities[['Lat', 'Lng']]
weights = cities['Humidity']
fig = gmaps.figure(map_type = 'HYBRID', center = (0,0), zoom_level = 3)
heat = gmaps.heatmap_layer(locations, weights = weights, max_intensity = 0, point_radius = 30)
fig.add_layer(heat)
#
fig
# Out:
# Known nbextensions:
#   config dir: C:\Users\chris\.jupyter\nbconfig
#     notebook section
#       jupyter-gmaps/extension enabled
#   config dir: C:\Users\chris\Anaconda3\etc\jupyter\nbconfig
#     notebook section
#       bqplot/extension enabled
#       ipyvolume/extension enabled
#       jupyter-webrtc/extension enabled
#       jupyter-datawidgets/extension enabled
#       jupyter-leaflet/extension enabled
#       jupyter-matplotlib/extension enabled
#       jupyter-threejs/extension enabled
#       jupyter-vue/extension enabled
#       jupyter-vuetify/extension enabled
#       jupyter-js-widgets/extension enabled
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
#       - Validating: ok
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a new DataFrame with idyllic weather conditions that can be used for 
#potential destinations for a vacation

hotels = cities.loc[(cities["Max Temp"] <= 80) & (cities["Max Temp"] >= 70) &(cities["Cloudiness"] == 0) &(cities["Wind Speed"] < 10)]
hotels
# Out:
#                     City Country          Date    Lat    Lng  Max Temp  \
# 0             lewisville      US  1.601927e+09  33.05 -96.99     79.00
# 63   santiago del estero      AR  1.601927e+09 -27.80 -64.26     76.48
# 65            alexandria      EG  1.601927e+09  31.22  29.96     77.88
# 155                  hit      IQ  1.601927e+09  33.64  42.83     77.05
# 168             akbarpur      IN  1.601927e+09  26.42  82.55     79.18
# 224                kifri      IQ  1.601927e+09  34.70  44.97     76.26
# 228               kharan      PK  1.601927e+09  28.58  65.42     71.35
# 284          thomasville      US  1.601927e+09  35.88 -80.08     71.01
# 368                matay      EG  1.601927e+09  28.42  30.78     76.53
# 370             kalmunai      LK  1.601927e+09   7.42  81.82     79.81
# 409          chake chake      TZ  1.601927e+09  -5.25  39.77     75.42
# 528            abu kamal      SY  1.601927e+09  34.45  40.92     74.26
# 534            karpathos      GR  1.601927e+09  35.51  27.21     78.80
# 565            morondava      MG  1.601927e+09 -20.28  44.28     75.34
#
#      Humidity  Cloudiness  Wind Speed
# 0        46.0         0.0        1.99
# 63       28.0         0.0        8.57
# 65       68.0         0.0        8.93
# 155      19.0         0.0        7.00
# 168      59.0         0.0        2.75
# 224      19.0         0.0        6.55
# 228      20.0         0.0        3.91
# 284      57.0         0.0        2.21
# 368      31.0         0.0        9.13
# 370      81.0         0.0        1.61
# 409      89.0         0.0        9.44
# 528      22.0         0.0        9.62
# 534      60.0         0.0        2.46
# 565      78.0         0.0        8.34

# %%
#Using Google Maps API, find a hotel within 5000 meters of each location and add the hotel to the dataFrame

hotels['Hotel Name'] = ''
params = {
    "radius": 5000, 
    "types": "lodging",
    "key": g_key}

for index, row in hotels.iterrows():
    city = row['City']
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    response = requests.get(url, params = params)
    response = response.json()
    try:
        print(f'Finding Lodging for {city}')
        print('----------------------------')
        hotels.loc[index, "Hotel Name"] = response["results"][0]["name"]
    except (KeyError, IndexError):
        print("No Lodging Found.")
        print('----------------------------')
        hotels.loc[index, "Hotel Name"] = "No Lodging Found"
        
hotels
# Out:
# C:\Users\chris\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Finding Lodging for lewisville
# ----------------------------
# C:\Users\chris\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Finding Lodging for santiago del estero
# ----------------------------
# Finding Lodging for alexandria
# ----------------------------
# Finding Lodging for hit
# ----------------------------
# Finding Lodging for akbarpur
# ----------------------------
# Finding Lodging for kifri
# ----------------------------
# Finding Lodging for kharan
# ----------------------------
# Finding Lodging for thomasville
# ----------------------------
# Finding Lodging for matay
# ----------------------------
# Finding Lodging for kalmunai
# ----------------------------
# Finding Lodging for chake chake
# ----------------------------
# Finding Lodging for abu kamal
# ----------------------------
# Finding Lodging for karpathos
# ----------------------------
# Finding Lodging for morondava
# ----------------------------
#                     City Country          Date    Lat    Lng  Max Temp  \
# 0             lewisville      US  1.601927e+09  33.05 -96.99     79.00
# 63   santiago del estero      AR  1.601927e+09 -27.80 -64.26     76.48
# 65            alexandria      EG  1.601927e+09  31.22  29.96     77.88
# 155                  hit      IQ  1.601927e+09  33.64  42.83     77.05
# 168             akbarpur      IN  1.601927e+09  26.42  82.55     79.18
# 224                kifri      IQ  1.601927e+09  34.70  44.97     76.26
# 228               kharan      PK  1.601927e+09  28.58  65.42     71.35
# 284          thomasville      US  1.601927e+09  35.88 -80.08     71.01
# 368                matay      EG  1.601927e+09  28.42  30.78     76.53
# 370             kalmunai      LK  1.601927e+09   7.42  81.82     79.81
# 409          chake chake      TZ  1.601927e+09  -5.25  39.77     75.42
# 528            abu kamal      SY  1.601927e+09  34.45  40.92     74.26
# 534            karpathos      GR  1.601927e+09  35.51  27.21     78.80
# 565            morondava      MG  1.601927e+09 -20.28  44.28     75.34
#
#      Humidity  Cloudiness  Wind Speed                            Hotel Name
# 0        46.0         0.0        1.99  Best Western Dallas-Lewisville Hotel
# 63       28.0         0.0        8.57                          Hotel Urbano
# 65       68.0         0.0        8.93                     Royal Crown Hotel
# 155      19.0         0.0        7.00                       Aboody Alhachem
# 168      59.0         0.0        2.75                   Hotel Aviral Palace
# 224      19.0         0.0        6.55                            میزان کفری
# 228      20.0         0.0        3.91                    Ghani Hasrat House
# 284      57.0         0.0        2.21          Comfort Inn Thomasville I-85
# 368      31.0         0.0        9.13                            Nag Aespen
# 370      81.0         0.0        1.61                              VS Villa
# 409      89.0         0.0        9.44                     Hotel Archipelago
# 528      22.0         0.0        9.62                          محطة التلفاز
# 534      60.0         0.0        2.46                                  Alex
# 565      78.0         0.0        8.34                        La Case Bambou

# %%
# Add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotels.iterrows()]
lodging = hotels[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# Display figure
hotel_plot = gmaps.symbol_layer(lodging, fill_color = 'red', stroke_color = 'blue', info_box_content = hotel_info)
fig.add_layer(hotel_plot)
#
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
