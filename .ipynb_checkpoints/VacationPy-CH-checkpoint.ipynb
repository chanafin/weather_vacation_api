# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import os
import gmaps
import gmaps.datasets
# Import API key
from api_keys import g_key
# Out:
# Requirement already satisfied: gmaps in c:\users\chris\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\chris\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\chris\anaconda3\lib\site-packages (from gmaps) (7.8.0)
# Requirement already satisfied: six in c:\users\chris\anaconda3\lib\site-packages (from gmaps) (1.12.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\chris\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\chris\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: decorator in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.15.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (41.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.0.10)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.1)
# Requirement already satisfied: pygments in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.4.2)
# Requirement already satisfied: backcall in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pickleshare in c:\users\chris\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: ipython-genutils in c:\users\chris\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\chris\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\chris\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\chris\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: parso>=0.5.0 in c:\users\chris\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.1)
# Requirement already satisfied: wcwidth in c:\users\chris\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.7)
# Requirement already satisfied: jupyter-core in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.5.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.0.2)
# Requirement already satisfied: tornado>=4.2 in c:\users\chris\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\chris\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\chris\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\chris\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\chris\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\chris\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (223)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\chris\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\chris\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (18.1.0)
# Requirement already satisfied: nbconvert in c:\users\chris\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.0)
# Requirement already satisfied: prometheus-client in c:\users\chris\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: Send2Trash in c:\users\chris\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\chris\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.10.3)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\chris\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.2)
# Requirement already satisfied: defusedxml in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: bleach in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: testpath in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chris\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: webencodings in c:\users\chris\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_cities = "City_data.csv"
df = pd.read_csv(clean_cities)
df.rename(columns = {'Unnamed: 0' : 'Drop'}, inplace = True)
del df['Drop']
#
df
# Out:
#              City Country          Date    Lat     Lng  Max Temp  Humidity  \
# 0        hermanus      ZA  1.590292e+09 -34.42   19.23     58.32      75.0
# 1       beisfjord      NO  1.590292e+09  68.38   17.60     48.20      61.0
# 2             gao      ML  1.590292e+09  16.64    1.64     76.14      16.0
# 3    puerto ayora      EC  1.590292e+09  -0.74  -90.35     73.00      92.0
# 4       tumbagaan      PH  1.590292e+09   5.37  120.31     86.29      69.0
# ..            ...     ...           ...    ...     ...       ...       ...
# 545          kolo      PL  1.590292e+09  52.20   18.64     51.01      96.0
# 546       eenhana     NaN  1.590292e+09 -17.47   16.33     57.20      62.0
# 547       ardakan      IR  1.590292e+09  32.31   54.02     73.40      14.0
# 548        beloha      MG  1.590292e+09 -25.17   45.05     64.11      88.0
# 549     high rock      BS  1.590292e+09  26.62  -78.28     78.06      80.0
#
#      Cloudiness  Wind Speed
# 0           0.0        7.23
# 1          80.0       13.87
# 2          47.0        4.63
# 3          18.0        1.01
# 4          23.0        7.61
# ..          ...         ...
# 545       100.0       10.94
# 546         0.0        4.70
# 547         0.0        4.70
# 548         2.0        7.11
# 549        85.0       18.30
#
# [550 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# !jupyter nbextension list
# !jupyter nbextension enable --py gmaps
from ipywidgets.embed import embed_minimal_html
#
gmaps.configure(api_key = g_key)
locations = df[['Lat', 'Lng']]
weights = df['Humidity']
fig = gmaps.figure(map_type = 'HYBRID', center = (0,0), zoom_level = 3)
heat = gmaps.heatmap_layer(locations, weights = weights, max_intensity = 0, point_radius = 30)
fig.add_layer(heat)
#
fig
# Out:
# Known nbextensions:
#   config dir: C:\Users\chris\.jupyter\nbconfig
#     notebook section
#       jupyter-gmaps/extension enabled
#   config dir: C:\Users\chris\Anaconda3\etc\jupyter\nbconfig
#     notebook section
#       jupyter-js-widgets/extension enabled
#       - Validating: ok
#       - Validating: ok
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df = df.loc[(df["Max Temp"] <= 80) & (df["Max Temp"] >= 70) &(df["Cloudiness"] == 0) &(df["Wind Speed"] < 10)]

hotel_df
# Out:
#            City Country          Date    Lat     Lng  Max Temp  Humidity  \
# 8    sao filipe      CV  1.590292e+09  14.90  -24.50     74.98      66.0
# 70     celestun      MX  1.590292e+09  20.87  -90.40     77.83      68.0
# 80         aksu      CN  1.590292e+09  41.12   80.26     79.92      17.0
# 91     linguere      SN  1.590292e+09  15.40  -15.12     72.68      58.0
# 117   caravelas      BR  1.590292e+09 -17.71  -39.25     72.30      93.0
# 179      nyurba      RU  1.590292e+09  63.28  118.33     77.41      33.0
# 186    teguldet      RU  1.590292e+09  57.31   88.17     71.53      38.0
# 261  toora-khem      RU  1.590292e+09  52.47   96.11     74.77      24.0
# 345      mehriz      IR  1.590292e+09  31.59   54.43     73.40      15.0
# 370    tessalit      ML  1.590292e+09  20.20    1.01     72.50      30.0
# 398    saryozek      KZ  1.590292e+09  44.36   77.98     73.71      36.0
# 426    havelock      US  1.590292e+09  34.88  -76.90     75.00      91.0
# 431     la cruz      MX  1.590292e+09  23.92 -106.90     73.00      88.0
# 468   kysyl-syr      RU  1.590292e+09  63.90  122.76     70.07      33.0
# 547     ardakan      IR  1.590292e+09  32.31   54.02     73.40      14.0
#
#      Cloudiness  Wind Speed
# 8           0.0        8.93
# 70          0.0        9.51
# 80          0.0        3.31
# 91          0.0        8.28
# 117         0.0        2.42
# 179         0.0        8.75
# 186         0.0        5.99
# 261         0.0        3.40
# 345         0.0        4.70
# 370         0.0        2.33
# 398         0.0        8.14
# 426         0.0        1.01
# 431         0.0        0.72
# 468         0.0        8.16
# 547         0.0        4.70

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name'] = ''
# Out:
# C:\Users\chris\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
params = {
    "radius": 5000, 
    "types": "lodging",
    "key": g_key}

for index, row in hotel_df.iterrows():
    city = row['City']
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    response = requests.get(url, params = params)
    response = response.json()
    try:
        print(f'Finding Lodging for {city}')
        print('----------------------------')
        hotel_df.loc[index, "Hotel Name"] = response["results"][0]["name"]
    except (KeyError, IndexError):
        print("No Lodging Found.")
        print('----------------------------')
        hotel_df.loc[index, "Hotel Name"] = "No Lodging Found"
# Out:
# Finding Lodging for sao filipe
# ----------------------------
# Finding Lodging for celestun
# ----------------------------
# Finding Lodging for aksu
# ----------------------------
# Finding Lodging for linguere
# ----------------------------
# Finding Lodging for caravelas
# ----------------------------
# Finding Lodging for nyurba
# ----------------------------
# Finding Lodging for teguldet
# ----------------------------
# Finding Lodging for toora-khem
# ----------------------------
# No Lodging Found.
# ----------------------------
# Finding Lodging for mehriz
# ----------------------------
# Finding Lodging for tessalit
# ----------------------------
# No Lodging Found.
# ----------------------------
# Finding Lodging for saryozek
# ----------------------------
# Finding Lodging for havelock
# ----------------------------
# Finding Lodging for la cruz
# ----------------------------
# Finding Lodging for kysyl-syr
# ----------------------------
# No Lodging Found.
# ----------------------------
# Finding Lodging for ardakan
# ----------------------------

# %%
hotel_df
# Out:
#            City Country          Date    Lat     Lng  Max Temp  Humidity  \
# 8    sao filipe      CV  1.590292e+09  14.90  -24.50     74.98      66.0
# 70     celestun      MX  1.590292e+09  20.87  -90.40     77.83      68.0
# 80         aksu      CN  1.590292e+09  41.12   80.26     79.92      17.0
# 91     linguere      SN  1.590292e+09  15.40  -15.12     72.68      58.0
# 117   caravelas      BR  1.590292e+09 -17.71  -39.25     72.30      93.0
# 179      nyurba      RU  1.590292e+09  63.28  118.33     77.41      33.0
# 186    teguldet      RU  1.590292e+09  57.31   88.17     71.53      38.0
# 261  toora-khem      RU  1.590292e+09  52.47   96.11     74.77      24.0
# 345      mehriz      IR  1.590292e+09  31.59   54.43     73.40      15.0
# 370    tessalit      ML  1.590292e+09  20.20    1.01     72.50      30.0
# 398    saryozek      KZ  1.590292e+09  44.36   77.98     73.71      36.0
# 426    havelock      US  1.590292e+09  34.88  -76.90     75.00      91.0
# 431     la cruz      MX  1.590292e+09  23.92 -106.90     73.00      88.0
# 468   kysyl-syr      RU  1.590292e+09  63.90  122.76     70.07      33.0
# 547     ardakan      IR  1.590292e+09  32.31   54.02     73.40      14.0
#
#      Cloudiness  Wind Speed                               Hotel Name
# 8           0.0        8.93                              Tortuga B&B
# 70          0.0        9.51                             Posada Lilia
# 80          0.0        3.31                     Pudong Holiday Hotel
# 91          0.0        8.28            Centre Amadou Seck - Linguere
# 117         0.0        2.42                   Pousada dos Navegantes
# 179         0.0        8.75                        Gostinitsa Alrosa
# 186         0.0        5.99                          Gostinitsa Kedr
# 261         0.0        3.40                         No Lodging Found
# 345         0.0        4.70            Mehrgard dwelling/سرای مهرگرد
# 370         0.0        2.33                         No Lodging Found
# 398         0.0        8.14                               Gostinitsa
# 426         0.0        1.01  Holiday Inn Express and Suites Havelock
# 431         0.0        0.72          Enedina Guadalupe Aguilar López
# 468         0.0        8.16                         No Lodging Found
# 547         0.0        4.70                            Ardakan Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
lodging = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# Display figure
hotel_plot = gmaps.symbol_layer(lodging, fill_color = 'red', stroke_color = 'blue', info_box_content = hotel_info)
fig.add_layer(hotel_plot)
#
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
